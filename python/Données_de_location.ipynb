# %%
#ici j'importe les bibliotheques que j'ai besoi pour mon tp
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#chargement des données d'entrainement
house_data = pd.read_csv('house.csv')
house_data = house_data[house_data['loyer'] < 10000]

# %%
#Affichage de notre nuange de données
plt.plot(house_data['surface'], house_data['loyer'], 'ro', markersize=4)
plt.show()

# %%
x = np.matrix([np.ones(house_data.shape[0]), house_data['surface']]).T
x[:10]
y = np.matrix([house_data['loyer']]).T
y[:10]
# Out:
# matrix([[1330],
#         [1400],
#         [ 904],
#         [ 955],
#         [2545],
#         [ 970],
#         [1560],
#         [1960],
#         [2000],
#         [2600]], dtype=int64)

# %%
theta = np.linalg.inv(x.T.dot(x)).dot(x.T).dot(y)
print(theta)
# Out:
# [[266.45460292]
#  [ 30.66119596]]

# %%
#ici je peux faire une prediction avec un appartement de surface 30 m2  
k = theta.item(0) + theta.item(1) * 35
print(k)
# Out:
# 1339.5964615602247

# %%
plt.xlabel('Surface')
plt.ylabel('Loyer')

plt.plot(house_data['surface'], house_data['loyer'], 'ro', markersize=4)

# On affiche la droite entre 0 et 250
plt.plot([0,250], [theta.item(0),theta.item(0) + 250 * theta.item(1)], linestyle='-', c='#000000')

plt.show()
