# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#chargement des données d'entrainement
pd.read_csv("abalone.csv", sep=";", names=["Longueur", "Diamètre", "Hauteur", "Poids total", "Poids de la chair", "Poids des organes", "Poids de la coquille","Age"])
# Out:
#      Longueur   Diamètre  Hauteur    Poids total Poids de la chair  \
# 0      Length   Diameter   Height   Whole_weight    Shucked_weight
# 1       0.455      0.365    0.095          0.514            0.2245
# 2        0.35      0.265     0.09         0.2255            0.0995
# 3        0.53       0.42    0.135          0.677            0.2565
# 4        0.44      0.365    0.125          0.516            0.2155
# ...       ...        ...      ...            ...               ...
# 4173    0.565       0.45    0.165          0.887              0.37
# 4174     0.59       0.44    0.135          0.966             0.439
# 4175      0.6      0.475    0.205          1.176            0.5255
# 4176    0.625      0.485     0.15         1.0945             0.531
# 4177     0.71      0.555    0.195         1.9485            0.9455
#
#      Poids des organes Poids de la coquille     Age
# 0       Viscera_weight         Shell_weight   Label
# 1                0.101                 0.15      15
# ...

# %%
df
# Out:
#      Longueur   Diamètre  Hauteur    Poids total Poids de la chair  \
# 0      Length   Diameter   Height   Whole_weight    Shucked_weight
# 1       0.455      0.365    0.095          0.514            0.2245
# 2        0.35      0.265     0.09         0.2255            0.0995
# 3        0.53       0.42    0.135          0.677            0.2565
# 4        0.44      0.365    0.125          0.516            0.2155
# ...       ...        ...      ...            ...               ...
# 4173    0.565       0.45    0.165          0.887              0.37
# 4174     0.59       0.44    0.135          0.966             0.439
# 4175      0.6      0.475    0.205          1.176            0.5255
# 4176    0.625      0.485     0.15         1.0945             0.531
# 4177     0.71      0.555    0.195         1.9485            0.9455
#
#      Poids des organes Poids de la coquille     Age
# 0       Viscera_weight         Shell_weight   Label
# 1                0.101                 0.15      15
# ...

# %%
#
#df.index
df.drop(df.loc[:0] == 0.index, inplace=True)
# Out:
#   File "<ipython-input-40-7f87564762f9>", line 3
#     df.drop(df.loc[:0] == 0.index, inplace=True)
#                             ^
# SyntaxError: invalid syntax

# %%
df
# Out:
#     Longueur Diamètre Hauteur Poids total Poids de la chair Poids des organes  \
# Age
# 15     0.455    0.365   0.095       0.514            0.2245             0.101
# 7       0.35    0.265    0.09      0.2255            0.0995            0.0485
# 9       0.53     0.42   0.135       0.677            0.2565            0.1415
# 10      0.44    0.365   0.125       0.516            0.2155             0.114
# 7       0.33    0.255    0.08       0.205            0.0895            0.0395
# ..       ...      ...     ...         ...               ...               ...
# 11     0.565     0.45   0.165       0.887              0.37             0.239
# 10      0.59     0.44   0.135       0.966             0.439            0.2145
# 9        0.6    0.475   0.205       1.176            0.5255            0.2875
# 10     0.625    0.485    0.15      1.0945             0.531             0.261
# 12      0.71    0.555   0.195      1.9485            0.9455            0.3765
#
#     Poids de la coquille
# ...
